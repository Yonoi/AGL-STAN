# %%
import numpy as np

# %%
filename = 'node_features_2015_4.npy'

# %%
data = np.load(filename)

# %%
data.shape
# Out:
# (365, 77, 4)

# %%
np.sum(data, axis=(0, 1))
# Out:
# array([15096., 44113., 16915., 20381.], dtype=float32)

# %%
adj_filename = 'adj_mat.npy'
